# %%
# synatx to cereate an object 

# objectname = classname()

#example

L=list()

# or for dtatypes 

L=[1,2,3]

# %%
# PASCAL CASE

# it is a naming convention in ehich each world starts from Captial later

#HelloWorld
#MyClass
